# %%
string = input("Enter a string: ")

if string.isalnum():
    print("String contains only alphabets and numbers.")
else:
    print("String contains special characters.")
# Out:
# Enter a string:  HELLO1548!
# String contains special characters.
